# %% [markdown]
# # Niye Python
#     Python
#     R
#     Pytorch
#     Java
#     JavaScript
#     C#
#     Julia
#     Matlab

# %% [markdown]
# #Nasıl Kurulur
#
# ###Kendi makineniz direk kurulum
#   https://www.python.org/downloads/
#
#   Her bir kütüphane kendi download sayfası yada pip
#
#   versiyon değişimi
#   farklı versiyon isteyen programlar
#
#   Hatalarda tüm ayarlar tekrar yapılacak
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ### Anaconda ile çalışmak
#
# console veya anaconda navigator
#
#
#
#
#
#
#
#
#
# #Bulut Sistemler
# Google,Amazon, Microsoft

# %% [markdown]
# #Editör
#
# ##kendi Pc
# PhyCharm,Spyder,notepad vs...
#
# ##Web tabanlı
# jupyter notebook
#
# ##Bulut tabanlı
# colab(jupyter notebook versiyonu)
# ...

# %%
g=9

# %%
g
# Out:
# 9

# %%
type(g)
# Out:
# int

# %% [markdown]
# #Python

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
if 5 > 2:
     print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
if 5 > 10:
  print("Five is greater than two!") 
print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
if 5 > 2:
    print("Five is greater than two!") 
if 5 > 2:
       print("Five is greater than two!")
# Out:
# Five is greater than two!
# Five is greater than two!

# %%
x = 5
y = "Hello, World!"

# %%
#Bu bir yorum
#ikinci satır
print(y)
# Out:
# Hello, World!

# %%
x, y, z = "Orange", "Banana", "Cherry"
print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
x = y = z = "Orange"
print(x)
print(y)
print(z)
# Out:
# Orange
# Orange
# Orange

# %%
x = "Python is "
y = "awesome"
z =  x + y
print(z)
# Out:
# Python is awesome

# %%
x = "awesome"

def myfunc():
  print("Python is " + x)

myfunc()
# Out:
# Python is awesome

# %%
x = "awesome"

def myfunc1():
  x = "fantastic"
  print("Python is " + x)

myfunc1()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is awesome

# %%
x = "awesome"
def myfunc():
  global x
  x = "fantastic"
  print("Python is " + x)

myfunc()

print("Python is " + x)
# Out:
# Python is fantastic
# Python is fantastic

# %%
x = "5."
print(type(x))
x
# Out:
# <class 'str'>
# '5.'

# %%
x = 1 # int
y = 2.8 # float
z = 1j # complex

#convert from int to float:
a = float(x)

#convert from float to int:
b = int(y)

#convert from int to complex:
c = complex(x)

print(a)
print(b)
print(c)
print(z)

print(type(a))
print(type(b))
print(type(c)) 
print(type(z))
# Out:
# 1.0
# 2
# (1+0j)
# 1j
# <class 'float'>
# <class 'int'>
# <class 'complex'>
# <class 'complex'>

# %%
import random

print(random.randrange(0,100))
# Out:
# 92

# %%
b = "Hello, World!"
print(b[3:6])
# Out:
# lo,

# %%
b[:]
# Out:
# 'Hello, World!'

# %%
b
# Out:
# 'Hello, World!'

# %%
b = "Hello, World!"
print(b[-5:-2])
# Out:
# orl

# %%
a = "Hello, World!"
print(len(a))
# Out:
# 13

# %%
txt = "The rain in Spain stays mainly in the plain"
x = "ain"   not in txt
print(x)
# Out:
# True

# %%
a = "Hello"
b = "World"
c = a + " " + b+str(9)
print(c)
# Out:
# Hello World9

# %%
print(10 > 9)
print(10 == 9)
print(10 < 9)
# Out:
# True
# False
# False

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
  print(x)
# Out:
# apple
# banana
# cherry

# %%
for x in "banana":
  print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
for x in range(6):
  print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for x in range(2, 6):
  print(x)
# Out:
# 2
# 3
# 4
# 5

# %%
for x in range(2, 33, 3):
  print(x)
# Out:
# 2
# 5
# 8
# 11
# 14
# 17
# 20
# 23
# 26
# 29
# 32

# %% [markdown]
# ### Çalışma Tavsiyesi
# python tutorial anahtar kelimeleri
